# %%
with open('jamilia.txt', 'r', encoding='utf-8') as fid:
    r=fid.read().split()
print(len(r))
# Out:
# 15367

# %%
def find_min_index(arr):
    minimum=float('inf')
    for i,j in enumerate(arr):
        if j<minimum:
            return i
    return None

# %%
def find_min_index(arr):
    minimum=float('inf')
    index=None
    for i,j in enumerate(arr):
        if j<minimum:
            index=i
    return i
with open('jamilia.txt', encoding='utf-8') as fid:
    f=fid.read().split()
    a=[-len(i.strip(',').strip('.')) for i in f]
    mini=find_min_index(a)
print(f[mini])
# Out:
# Умново.ру

# %%
def find_min_index(arr):
    minimum = float('inf')
    index = None
    for i, j in enumerate(arr):
        if j < minimum:
            minimum = j
            index = i
    return index

with open('jamilia.txt', encoding='utf-8') as fid:
    f = fid.read().split()
    a = [-len(i.strip(',').strip('.')) for i in f]
    mini = find_min_index(a)
print(f[mini])
# Out:
# ГлавнаяАвторыПроизведенияСтихиКак
